# %%
import pandas as pd
import numpy as np
city = pd.read_csv('chicago.csv')

# %%
city['Department'] = city['Department'].astype('category')

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  category
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: category(1), object(3)
# memory usage: 784.4+ KB

# %%
city.dropna(how='all',inplace=True)

# %%
city
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER       WATER MGMNT
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV       WATER MGMNT
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# ...

# %%
city.tail()
# Out:
#                       Name                  Position Title        Department  \
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# 32057              $99528.00
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
city['Department'] = city['Department'].str.replace('MGMNT', 'Management')

# %%
city
# Out:
#                       Name                  Position Title        Department  \
# 0          AARON,  ELVIA J                WATER RATE TAKER  WATER Management
# 1        AARON,  JEFFERY M                  POLICE OFFICER            POLICE
# 2           AARON,  KARINA                  POLICE OFFICER            POLICE
# 3      AARON,  KIMBERLEI R        CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4      ABAD JR,  VICENTE M               CIVIL ENGINEER IV  WATER Management
# ...                    ...                             ...               ...
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# ...

# %%
city['Name'] = city['Name'].str.title()
city['Position Title'] = city['Position Title'].str.title()
city['Department'] = city['Department'].str.title()
city['Employee Annual Salary'] = city['Employee Annual Salary'].str.replace('$','')
city['Employee Annual Salary'] = city['Employee Annual Salary'].astype(float)

# %%
city
# Out:
#                       Name                  Position Title        Department  \
# 0          Aaron,  Elvia J                Water Rate Taker  Water Management
# 1        Aaron,  Jeffery M                  Police Officer            Police
# 2           Aaron,  Karina                  Police Officer            Police
# 3      Aaron,  Kimberlei R        Chief Contract Expediter  General Services
# 4      Abad Jr,  Vicente M               Civil Engineer Iv  Water Management
# ...                    ...                             ...               ...
# 32057  Zygadlo,  Michael J  Frm Of Machinists - Automotive  General Services
# 32058   Zygowicz,  Peter J                  Police Officer            Police
# 32059    Zymantas,  Mark E                  Police Officer            Police
# 32060  Zyrkowski,  Carlo E                  Police Officer            Police
# 32061  Zyskowski,  Dariusz         Chief Data Base Analyst              Doit
#
#        Employee Annual Salary
# ...

# %%
dict(city.dtypes)
# Out:
# {'Name': dtype('O'),
#  'Position Title': dtype('O'),
#  'Department': dtype('O'),
#  'Employee Annual Salary': dtype('float64')}

# %%
city['Employee Annual Salary'].min()
# Out:
# 0.96

# %%
city[city['Position Title'].str.startswith('Water')]
# Out:
#                          Name           Position Title        Department  \
# 0             Aaron,  Elvia J         Water Rate Taker  Water Management
# 671           Ander,  Perry A         Water Chemist Ii  Water Management
# 1054         Ashley,  Karma T         Water Chemist Ii  Water Management
# 1079        Atkins,  Joanna M         Water Chemist Ii  Water Management
# 1181       Azeem,  Mohammed A         Water Chemist Ii  Water Management
# ...                       ...                      ...               ...
# 28574      Threatt,  Denise R  Water Quality Inspector  Water Management
# 28602       Tignor,  Darryl B         Water Rate Taker  Water Management
# 28955  Travis Cook,  Leslie R         Water Rate Taker  Water Management
# 29584        Velazquez,  John         Water Rate Taker  Water Management
# 30239     Washington,  Joseph        Water Chemist Iii  Water Management
#
#        Employee Annual Salary
# 0                     90744.0
# ...

# %%
var.str.lstrip()
# Out:
# 0                      Water Rate Taker
# 1                        Police Officer
# 2                        Police Officer
# 3              Chief Contract Expediter
# 4                     Civil Engineer Iv
#                       ...
# 32057    Frm Of Machinists - Automotive
# 32058                    Police Officer
# 32059                    Police Officer
# 32060                    Police Officer
# 32061           Chief Data Base Analyst
# Name: Position Title, Length: 32062, dtype: object

# %%
'    hello world     '.strip()
# Out:
# 'hello world'

# %%
city['Name'] = city['Name'].str.strip()

# %%
city
# Out:
#                       Name                  Position Title        Department  \
# 0          Aaron,  Elvia J                Water Rate Taker  Water Management
# 1        Aaron,  Jeffery M                  Police Officer            Police
# 2           Aaron,  Karina                  Police Officer            Police
# 3      Aaron,  Kimberlei R        Chief Contract Expediter  General Services
# 4      Abad Jr,  Vicente M               Civil Engineer Iv  Water Management
# ...                    ...                             ...               ...
# 32057  Zygadlo,  Michael J  Frm Of Machinists - Automotive  General Services
# 32058   Zygowicz,  Peter J                  Police Officer            Police
# 32059    Zymantas,  Mark E                  Police Officer            Police
# 32060  Zyrkowski,  Carlo E                  Police Officer            Police
# 32061  Zyskowski,  Dariusz         Chief Data Base Analyst              Doit
#
#        Employee Annual Salary
# ...

# %%
city.set_index(city['Name'],inplace=True)

# %%
city
# Out:
#                                     Name                  Position Title  \
# Name
# Aaron,  Elvia J          Aaron,  Elvia J                Water Rate Taker
# Aaron,  Jeffery M      Aaron,  Jeffery M                  Police Officer
# Aaron,  Karina            Aaron,  Karina                  Police Officer
# Aaron,  Kimberlei R  Aaron,  Kimberlei R        Chief Contract Expediter
# Abad Jr,  Vicente M  Abad Jr,  Vicente M               Civil Engineer Iv
# ...                                  ...                             ...
# Zygadlo,  Michael J  Zygadlo,  Michael J  Frm Of Machinists - Automotive
# Zygowicz,  Peter J    Zygowicz,  Peter J                  Police Officer
# Zymantas,  Mark E      Zymantas,  Mark E                  Police Officer
# Zyrkowski,  Carlo E  Zyrkowski,  Carlo E                  Police Officer
# Zyskowski,  Dariusz  Zyskowski,  Dariusz         Chief Data Base Analyst
#
#                            Department  Employee Annual Salary
# Name
# ...

# %%
city.index = city.index.str.strip().str.title()

# %%
city
# Out:
#                                     Name                  Position Title  \
# Name
# Aaron,  Elvia J          Aaron,  Elvia J                Water Rate Taker
# Aaron,  Jeffery M      Aaron,  Jeffery M                  Police Officer
# Aaron,  Karina            Aaron,  Karina                  Police Officer
# Aaron,  Kimberlei R  Aaron,  Kimberlei R        Chief Contract Expediter
# Abad Jr,  Vicente M  Abad Jr,  Vicente M               Civil Engineer Iv
# ...                                  ...                             ...
# Zygadlo,  Michael J  Zygadlo,  Michael J  Frm Of Machinists - Automotive
# Zygowicz,  Peter J    Zygowicz,  Peter J                  Police Officer
# Zymantas,  Mark E      Zymantas,  Mark E                  Police Officer
# Zyrkowski,  Carlo E  Zyrkowski,  Carlo E                  Police Officer
# Zyskowski,  Dariusz  Zyskowski,  Dariusz         Chief Data Base Analyst
#
#                            Department  Employee Annual Salary
# Name
# ...

# %%
city.head()
# Out:
#                                     Name            Position Title  \
# Name
# Aaron,  Elvia J          Aaron,  Elvia J          Water Rate Taker
# Aaron,  Jeffery M      Aaron,  Jeffery M            Police Officer
# Aaron,  Karina            Aaron,  Karina            Police Officer
# Aaron,  Kimberlei R  Aaron,  Kimberlei R  Chief Contract Expediter
# Abad Jr,  Vicente M  Abad Jr,  Vicente M         Civil Engineer Iv
#
#                            Department  Employee Annual Salary
# Name
# Aaron,  Elvia J      Water Management                 90744.0
# Aaron,  Jeffery M              Police                 84450.0
# Aaron,  Karina                 Police                 84450.0
# Aaron,  Kimberlei R  General Services                 89880.0
# Abad Jr,  Vicente M  Water Management                106836.0

# %%
city.columns = city.columns.str.lower().str.replace(' ', '_')

# %%
city
# Out:
#                                     name                  position_title  \
# Name
# Aaron,  Elvia J          Aaron,  Elvia J                Water Rate Taker
# Aaron,  Jeffery M      Aaron,  Jeffery M                  Police Officer
# Aaron,  Karina            Aaron,  Karina                  Police Officer
# Aaron,  Kimberlei R  Aaron,  Kimberlei R        Chief Contract Expediter
# Abad Jr,  Vicente M  Abad Jr,  Vicente M               Civil Engineer Iv
# ...                                  ...                             ...
# Zygadlo,  Michael J  Zygadlo,  Michael J  Frm Of Machinists - Automotive
# Zygowicz,  Peter J    Zygowicz,  Peter J                  Police Officer
# Zymantas,  Mark E      Zymantas,  Mark E                  Police Officer
# Zyrkowski,  Carlo E  Zyrkowski,  Carlo E                  Police Officer
# Zyskowski,  Dariusz  Zyskowski,  Dariusz         Chief Data Base Analyst
#
#                            department  employee_annual_salary
# Name
# ...

# %%
city['name'].str.split(',').str.get(0)
# Out:
# Name
# Aaron,  Elvia J            Aaron
# Aaron,  Jeffery M          Aaron
# Aaron,  Karina             Aaron
# Aaron,  Kimberlei R        Aaron
# Abad Jr,  Vicente M      Abad Jr
#                          ...
# Zygadlo,  Michael J      Zygadlo
# Zygowicz,  Peter J      Zygowicz
# Zymantas,  Mark E       Zymantas
# Zyrkowski,  Carlo E    Zyrkowski
# Zyskowski,  Dariusz    Zyskowski
# Name: name, Length: 32062, dtype: object

# %%
var.str.get(0)
# Out:
# 0        W
# 1        P
# 2        P
# 3        C
# 4        C
#         ..
# 32057    F
# 32058    P
# 32059    P
# 32060    P
# 32061    C
# Name: Position Title, Length: 32062, dtype: object

# %%
city['name'].str.split(',').str.get(1).str.strip().str.split(' ').str.get(0).value_counts()
# Out:
# Michael     1153
# John         899
# James        676
# Robert       622
# Joseph       537
#             ...
# Lambers        1
# Fazal          1
# Develle        1
# Malissia       1
# Jezieel        1
# Name: name, Length: 5091, dtype: int64

# %%
city[["first_name",'last_name']] = city['name'].str.split(',',expand=True)

# %%
city
# Out:
#                                     name                  position_title  \
# Name
# Aaron,  Elvia J          Aaron,  Elvia J                Water Rate Taker
# Aaron,  Jeffery M      Aaron,  Jeffery M                  Police Officer
# Aaron,  Karina            Aaron,  Karina                  Police Officer
# Aaron,  Kimberlei R  Aaron,  Kimberlei R        Chief Contract Expediter
# Abad Jr,  Vicente M  Abad Jr,  Vicente M               Civil Engineer Iv
# ...                                  ...                             ...
# Zygadlo,  Michael J  Zygadlo,  Michael J  Frm Of Machinists - Automotive
# Zygowicz,  Peter J    Zygowicz,  Peter J                  Police Officer
# Zymantas,  Mark E      Zymantas,  Mark E                  Police Officer
# Zyrkowski,  Carlo E  Zyrkowski,  Carlo E                  Police Officer
# Zyskowski,  Dariusz  Zyskowski,  Dariusz         Chief Data Base Analyst
#
#                            department  employee_annual_salary first_name  \
# Name
# ...

# %%
city.insert()
