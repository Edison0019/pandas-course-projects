# %%
import pandas as pd

# %%
emp = pd.read_csv('employees.csv')

# %%
emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
emp['Gender'] = emp['Gender'].astype('category')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 933 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             795 non-null    category
#  2   Start Date         933 non-null    datetime64[ns]
#  3   Last Login Time    933 non-null    datetime64[ns]
#  4   Salary             933 non-null    int32
#  5   Bonus %            933 non-null    float64
#  6   Senior Management  933 non-null    bool
#  7   Team               899 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int32(1), object(1)
# memory usage: 43.3+ KB

# %%
emp
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-08-28 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-08-28 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-08-28 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-08-28 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-08-28 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-08-28 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-08-28 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-08-28 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-08-28 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-08-28 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
emp.dropna(inplace=True,subset=["First Name"])

# %%
emp
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-08-28 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-08-28 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-08-28 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-08-28 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-08-28 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-08-28 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-08-28 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-08-28 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-08-28 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-08-28 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 933 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             795 non-null    object
#  2   Start Date         933 non-null    datetime64[ns]
#  3   Last Login Time    933 non-null    datetime64[ns]
#  4   Salary             933 non-null    int32
#  5   Bonus %            933 non-null    float64
#  6   Senior Management  933 non-null    object
#  7   Team               899 non-null    category
# dtypes: category(1), datetime64[ns](2), float64(1), int32(1), object(3)
# memory usage: 56.0+ KB

# %%
emp[emp['First Name'] == None]
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %% [markdown]
# ## Apart from here we are going to start with the analysis

# %%
emp.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-08-28 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-08-28 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-08-28 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2020-08-28 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2020-08-28 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
emp[(emp['Gender'] == 'Male') 
    
    &
    
    (emp['Team'] == 'Finance')]
# Out:
#       First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 3          Jerry   Male 2005-03-04 2020-08-28 13:00:00  138705    9.340
# 46         Bruce   Male 2009-11-28 2020-08-28 22:47:00  114796    6.796
# 56          Carl   Male 2006-05-03 2020-08-28 17:55:00  130276   16.084
# 68          Jose   Male 2004-10-30 2020-08-28 13:39:00   84834   14.330
# 83         Shawn   Male 2005-09-23 2020-08-28 02:55:00  148115    6.539
# 117       Steven   Male 1995-03-01 2020-08-28 15:03:00  109095    9.494
# 200         Gary   Male 1987-08-12 2020-08-28 00:04:00   89661    8.525
# 205      Brandon   Male 2006-03-27 2020-08-28 17:54:00  115711    8.012
# 219        Billy   Male 1995-03-13 2020-08-28 12:05:00  120444    7.768
# 222        Jason   Male 1999-10-17 2020-08-28 22:09:00   78417    3.067
# 241       Walter   Male 1983-07-06 2020-08-28 23:54:00  127813    5.961
# 286         Todd   Male 1984-02-02 2020-08-28 10:13:00   69989   10.985
# ...

# %%
emp[emp['Senior Management']]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-08-28 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-08-28 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2020-08-28 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-08-28 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2020-08-28 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2020-08-28 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-08-28 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-08-28 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2020-08-28 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2020-08-28 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
emp[emp['Team'] != 'Marketing']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-08-28 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-08-28 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-08-28 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-08-28 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-08-28 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-08-28 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-08-28 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-08-28 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-08-28 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-08-28 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
emp[emp.index == 4]
# Out:
#   First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 4      Larry   Male 1998-01-24 2020-08-28 16:47:00  101004    1.389
#
#    Senior Management             Team
# 4               True  Client Services

# %%
emp['Last Login Time'] - emp['Start Date']
# Out:
# 0      9884 days 12:42:00
# 1      8916 days 06:53:00
# 2      9989 days 11:17:00
# 3      5656 days 13:00:00
# 4      8252 days 16:47:00
#               ...
# 995    2105 days 06:09:00
# 996   13359 days 06:30:00
# 997    2657 days 12:39:00
# 998    2687 days 16:45:00
# 999    3027 days 18:24:00
# Length: 933, dtype: timedelta64[ns]

# %%
emp[(emp['Gender'] == 'Male') & (emp['Team'] == 'Marketing')]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-08-28 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2020-08-28 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2020-08-28 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2020-08-28 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2020-08-28 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2020-08-28 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2020-08-28 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2020-08-28 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2020-08-28 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2020-08-28 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2020-08-28 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2020-08-28 09:45:00   55281    4.935
# ...

# %%
emp.iloc[1][2]
# Out:
# Timestamp('1996-03-31 00:00:00')

# %%
emp[(emp['Senior Management']  == False) | (emp['Start Date'] <= '1990-01-01')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-08-28 11:17:00  130590   11.858
# 5       Dennis    Male 1987-04-18 2020-08-28 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-08-28 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2020-08-28 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2020-08-28 01:08:00  112807   17.492
# ..         ...     ...        ...                 ...     ...      ...
# 990      Robin  Female 1987-07-24 2020-08-28 13:35:00  100765   10.982
# 995      Henry     NaN 2014-11-23 2020-08-28 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-08-28 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-08-28 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-08-28 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
emp.loc[0]
# Out:
# First Name                       Douglas
# Gender                              Male
# Start Date           1993-08-06 00:00:00
# Last Login Time      2020-08-28 12:42:00
# Salary                             97308
# Bonus %                            6.945
# Senior Management                   True
# Team                           Marketing
# Name: 0, dtype: object
